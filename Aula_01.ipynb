# %%
print('Olá, você')
# Out:
# Olá, você

# %%
nome = 'Eduardo'
idade = 18
print(nome , idade)
# Out:
# Eduardo 18

# %%
nome = 'Albedo'
print('Olá,', nome)
# Out:
# Olá, Albedo

# %%
nome = 'Albedo' #Simplesmente ela.
idade = 37
altura = 1.75
rainha = True

print('Qual é o seu nome?', nome, 'Qual é a sua idade?', idade , 'Qual é a sua altura?' , altura , 'Você é a rainha?', rainha)
type(nome)
# Out:
# Qual é o seu nome? Albedo Qual é a sua idade? 37 Qual é a sua altura? 1.75 Você é a rainha? True
# str

# %%
pessoa = 1234
print(pessoa)
type(pessoa)
# Out:
# 1234
# int

# %%
idade1 = 20
idade2 = 35
S_idade = idade1 + idade2

print(S_idade)

sub_idade = idade1 - idade2
m_idade = idade1 * idade2
div_idade = idade1 / idade2

print(S_idade , sub_idade , m_idade , div_idade)

Add_idade = idade1 + 10
Subs_idade = idade1 - 10
multi_idade = idade1 * 2
divi_idade = idade1 / 2

print(Add_idade , Subs_idade , multi_idade , divi_idade)

teste1 = 2 * (idade1 + idade2)
teste2 = 2 * idade1 + 3 * idade2 / 4
teste3 = (2 * idade1 + 3 *idade2) / 4

print(teste1 , teste2 , teste3)

expo_idade = idade1 ** 3
print(expo_idade)

ParteInt_idade = idade2 // idade1

print(ParteInt_idade)

Mod_idade = idade2 % idade1

print(Mod_idade)
# Out:
# 55
# 55 -15 700 0.5714285714285714
# 30 10 40 10.0
# 110 66.25 36.25
# 8000
# 1
# 15

# %%
nome = 'Eduardo'
sobrenome = 'Camelo'
print(nome + ' ' + sobrenome)
print(nome , sobrenome)
# Out:
# Eduardo Camelo
# Eduardo Camelo

# %%
nome = 'Albedo'
idade = 37
altura = 1.75
rainha = True

print(' Qual é o seu nome? ' + nome, '\n' , 'Qual é a sua idade? ' , idade - 17 ,'anos','\n' ,'Qual é a sua altura(em metros)?' , altura, '\n' ,'Você é a rainha?', rainha)
# Out:
#  Qual é o seu nome? Albedo
#  Qual é a sua idade?  20 anos
#  Qual é a sua altura(em metros)? 1.75
#  Você é a rainha? True

# %%
input('Digite o nome dela: ')
nome = input('Digite seu nome: ')
# Out:
# Digite o nome dela: Albedo
# Digite seu nome: Eduardo

# %%
nome = str(input('life or soul? '))
# Out:
# life or soul? Life

# %%
x = 2 ** 2 ** 3 * 3
print(x)
# Out:
# 768
